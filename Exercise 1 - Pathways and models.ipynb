# %% [markdown]
# # Exercise 1
#
# Building and simulation pathways using COBRApy
#
# ![alt text](histidine_pathway_encyclopedia_microbiology.png)
#
#
# Simulating histidine biosynthesis
#  1. Initiate empty model
#  2. Add the metabolites that participat in the pathway
#  3. Populated the model the *E. coli* pathway to synthesize L-histidine from Ribose

# %%
import cobra
import escher

# %%
builder = escher.Builder(map_json='histidine_ribose_map.json')
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="dafhiexewx"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"dafhiexewx"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
1993.48166484375},"b2":{"x":3475.038419921875,"y":1993.48166484375}},"1181":{"from_node_id":"2076595","to_node_id":"2076598","b1":{"x":3653.288419921875,"y":1993.48166484375},"b2":{"x":3707.538419921875,"y":1993.48166484375}}}},"2076054":{"name":"Phosphoribosyl-ATP pyrophosphatase","bigg_id":"PRATPP","reversibility":false,"label_x":3891.288419921875,"label_y":1953.48166484375,"gene_reaction_rule":"b2026","genes":[{"notes":{"original_bigg_ids":["dcmp_e","FACOAL100t2pp","b2026"]},"name":"hisI","bigg_id":"b2026"}],"metabolites":[{"bigg_id":"ppi_c","coefficient":1},{"bigg_id":"prbamp_c","coefficient":1},{"bigg_id":"h_c","coefficient":1},{"bigg_id":"h2o_c","coefficient":-1},{"bigg_id":"prbatp_c","coefficient":-1}],"segments":{"1182":{"from_node_id":"2076599","to_node_id":"2076600","b1":null,"b2":null},"1183":{"from_node_id":"2076601","to_node_id":"2076600","b1":null,"b2":null},"1184":{"from_node_id":"2076601","to_node_id":"2076602","b1":{"x":4007.288419921875,"y":1993.48166484375},"b2":{"x":4012.538419921875,"y":1975.48166484375}},"1185":{"from_node_id":"2076601","to_node_id":"2076603","b1":{"x":4003.288419921875,"y":1993.48166484375},"b2":{"x":4057.538419921875 ...

# %%
# Initiate empty model
model = cobra.Model()

# with no reactions
print('Number of reactions: ' + str(len(model.reactions)))
print('Number of metabolites: ' + str(len(model.metabolites)))
# Out:
# Number of reactions: 0
# Number of metabolites: 0

# %%
from histidine_pathway import metabolites_and_info, reactions_and_info

# %%
import pandas as pd
pd.DataFrame.from_dict(reactions_and_info).T.to_csv('reactions_and_info.csv')

# %% [markdown]
# ---------
# ## Adding metabolites in pathway

# %%
print(metabolites_and_info['his__L_c'])
# Out:
# {'charge': 0, 'compartment': 'c', 'formula': 'C6H9N3O2', 'name': 'L-Histidine'}

# %%
# Start with adding a single metabolite with the above associated information
met = cobra.Metabolite(id='his__L_c', compartment='c', charge=0, formula='C6H9N3O2', name='L-histidine')

# %%
# Still no metabolites in model
print('Number of metabolites:' + str(len(model.metabolites)))
# Out:
# Number of metabolites:0

# %%
# Need to manually add it
model.add_metabolites(met)
print('Number of metabolites:' + str(len(model.metabolites)))
# Out:
# Number of metabolites:1

# %%
# Can access or edit the metabolite by either
model.metabolites.his__L_c
# or
model.metabolites.get_by_id('his__L_c')
# Out:
# <Metabolite his__L_c at 0x7f7fead5e160>

# %%
# Add all the remaining metabolites involved in the pathway
for met_id, info in metabolites_and_info.items():
    met = cobra.Metabolite(met_id, name=info['name'], formula=info['formula'], 
                           charge=info['charge'], compartment=info['compartment'])
    model.add_metabolites(met)

# %%
# Need to manually add it
print('Number of metabolites:' + str(len(model.metabolites)))
# Out:
# Number of metabolites:29

# %% [markdown]
# -------
# ## Adding reactions in pathway

# %%
print(reactions_and_info['HISTD'])
# Out:
# {'lower_bound': 0.0, 'name': 'histidinol dehydrogenase', 'stoichiometry': {'h2o_c': -1.0, 'h_c': 3.0, 'his__L_c': 1.0, 'histd_c': -1.0, 'nad_c': -2.0, 'nadh_c': 2.0}, 'upper_bound': 1000.0}

# %%
rxn = cobra.Reaction(id='HISTD', name='histidinol dehydrogenase')
rxn.upper_bound = 1000. # this is effectively infinity
rxn.lower_bound = 0 # irreversible
rxn.add_metabolites({'h2o_c': -1.0, 'h_c': 3.0, 'his__L_c': 1.0, 
                    'histd_c': -1.0, 'nad_c': -2.0, 'nadh_c': 2.0})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-943ef102d1d8> in <module>()
#       3 rxn.lower_bound = 0 # irreversible
#       4 rxn.add_metabolites({'h2o_c': -1.0, 'h_c': 3.0, 'his__L_c': 1.0,
# ----> 5                     'histd_c': -1.0, 'nad_c': -2.0, 'nadh_c': 2.0})
#
# ~/Envs/qbio18/lib/python3.6/site-packages/cobra/core/reaction.py in add_metabolites(self, metabolites_to_add, combine, reversibly)
#     776                                      "model or use Metabolite objects instead "
#     777                                      "of strings as keys."
# --> 778                                      % self.id)
#     779                 self._metabolites[metabolite] = coefficient
#     780                 # make the metabolite aware that it is involved in this
#
# ValueError: Reaction 'HISTD' does not belong to a model. Either add the reaction to a model or use Metabolite objects instead of strings as keys.

# %%
# Need to add reaction to model to access metabolites we have added
model.add_reactions([rxn])
rxn.add_metabolites({'h2o_c': -1.0, 'h_c': 3.0, 'his__L_c': 1.0, 
                    'histd_c': -1.0, 'nad_c': -2.0, 'nadh_c': 2.0})
print(rxn.reaction)
# Out:
# h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his__L_c + 2.0 nadh_c

# %%
# Upper and lower bound sets a reversibility on reactions
rxn.lower_bound = -1000
print(rxn.reaction)
# Return it back to irreversible
rxn.lower_bound = 0
# Out:
# h2o_c + histd_c + 2.0 nad_c <=> 3.0 h_c + his__L_c + 2.0 nadh_c

# %%
# Optimize
model.optimize()
# Out:
# <Solution 0.000 at 0x7f7feab32780>

# %% [markdown]
# Add boundary reactions to act as source and sink for ribose and histidine

# %%
rxn = cobra.Reaction('EX_rib__D_e')
model.add_reaction(rxn)
rxn.add_metabolites({'rib__D_e': -1})
rxn.lower_bound = -10 # by convention negative exchange flux = uptake

rxn = cobra.Reaction('EX_his__L_e')
model.add_reaction(rxn)
rxn.add_metabolites({'his__L_e': -1})

model.optimize()
# Out:
# <Solution 0.000 at 0x7f7feaaf9390>

# %% [markdown]
# **Still no flux through the reaction?  Why?**
#
# Flux balance analysis assumes that the system is opperating at steady state (meaning the concentration of the metabolites in the system do not increase or decrease over time). As a consequence of this, each metabolite that participates in the pathway must be created and consumed at the same rate.

# %%
iml = cobra.io.load_json_model('iML1515.json')
import cobra.test
#iml = cobra.test.create_test_model('ecoli')
iml.reactions.EX_glc__D_e.lower_bound = 0
iml.reactions.EX_o2_e.lower_bound = -1000
iml.reactions.EX_rib__D_e.lower_bound = -10
iml.reactions.ATPM.lower_bound = 0
iml.objective = 'EX_his__L_e'
#iml.optimize()
solution = cobra.flux_analysis.pfba(iml)

# %%
# Find number of reactions that must be active to produce histidine from ribose
active = 0
enzymatic = 0
for r in iml.reactions:
    if abs(r.x) > 1e-10:
        active += 1
        if r.gene_reaction_rule not in  ['s0001', '']:
            enzymatic += 1
            
print('Maximum histidine production flux:', round(solution.fluxes['EX_his__L_e'], 3))
print('Reactions active:', active)
print('Enzymatic reactions active:', enzymatic)
# Out:
# Maximum histidine production flux: 6.638
# Reactions active: 78
# Enzymatic reactions active: 69

# %%
builder = escher.Builder(map_json='primer_iML_map.json', 
                         reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'value', 'value': .01, 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#0000dd', 'size': 20}])
builder.reaction_data = solution.fluxes.to_dict()
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="puojxtxrbp"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"puojxtxrbp"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"ALATA_D2": 0.0, "SHCHD2": 0.0, "CPPPGO": 0.0, "GTHOr": 0.0, "DHORD5": 0.0, "GLYCTO2": 0.0, "GLYCTO3": 0.0, "GLYCTO4": 0.0, "PFK_3": 0.707423580786035, "TRPS2": 0.0, "G3PD5": 0.0, "EX_acgam_e": 0.0, "EX_cellb_e": 0.0, "EX_chol_e": 0.0, "LEUTAi": 0.0, "SHK3Dr": 0.0, "G5SD": 0.0, "ALATA_L2": 0.0, "MAN6PI": 0.0, "APRAUR": 0.0, "DB4PS": 0.0, "RBFK": 0.0, "ACP1_FMN": 0.0, "RBFSb": 0.0, "EX_pi_e": -2.972367707944522e-15, "EX_h_e": 19.912663755458517, "DMATT": 0.0, "GRTT": 6.953070014315613e-16, "UPP3S": 0.0, "UPPDC1": 0.0, "TMDPP": 0.0, "EX_ade_e": 0.0, "EX_4abut_e": 0.0, "EX_ac_e": 0.0, "EX_akg_e": 0.0, "EX_ala__L_e": 0.0, "EX_arg__L_e": 0.0, "EX_asp__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dcyt_e": 0.0, "EX_fum_e": 0.0, "EX_glu__L_e": 0.0, "EX_gua_e": 0.0, "HCO3E": 0.0, "IMPC": -6.637554585152849, "IMPD": 0.0, "ECOAH4": -6.644013380762052e-32, "GLUTRS": 0.0, "TMPPP": 0.0, "URIK1": 0.0, "URIK2": 0.0, "CYTDK1": 0.0, "CYTDK2": 0.0, "XPPT": 0.0, "HXPRT": 0.0, "NDPK5": 0.0, "DHORTS": 0.0, "OMPDC": 0.0, "CS": 0.7510917030567733, "ICDHyr": 0.7510917030567742, "ACALD": 0.0, "ACS": 0.0, "PPA": 13.275109170305708, "PPCK": 0.0, "ME1": 0.0, "ALAR": 0.0, "ALATA_L": 0.0, "XYLK": 0.0, "RBK": 10.0, "GLYK": 1.5440657195909917e-32, "PPM": 0.0, "ASPTA": -6.637554585152848, "FBP": 0.0, "GLGC": 0.0, "PYK": 0.0, "A5PISO": 0.0, "EX_met__L_e": 0.0, "EX_metsox_S__L_e": 0.0, "IPPMIb": 0.0, "ACHBS": 0.0, "ACLS": 0.0, "PSCVT": -2.277060706512961e-15, "ANS": 0.0, "ANPRT": 0.0, "CHORM": 0.0, "CHORS": -2.277060706512961e-15, "IGPS": 0.0, "EX_crn_e": 0.0, "EX_fe3_e": 0.0, "EX_glcn_e": 0.0, "EX_gln__L_e": 0.0, "EX_glyc_e": 0.0, "EX_man_e": 0.0, "EX_mn2_e": 0.0, "EX_rib__D_e": -10.0, "EX_sbt__D_e": 0.0, "ECOAH6": -6.644013380762052e-32, "ENO": 0.7510917030567841, "FBA": 0.0, "MGSA": 0.0, "PPS": 0.0, "PGI": -4.602620087336242, "PGK": -4.069868995633208, "EDA": 0.0
iml.reactions.EX_o2_e.lower_bound = 0
solution = cobra.flux_analysis.pfba(iml)

# Find number of reactions that must be active to produce histidine from ribose
active = 0
enzymatic = 0
for r in iml.reactions:
    if abs(r.x) > 1e-10:
        active += 1
        if r.gene_reaction_rule not in  ['s0001', '']:
            enzymatic += 1
print('Maximum histidine production flux:', round(solution.fluxes['EX_his__L_e'], 3))
print('Anaerobic reactions active:', active)
print('Anaerobic Enzymatic reactions active:', enzymatic)
# Out:
# Maximum histidine production flux: 0.915
# Anaerobic reactions active: 68
# Anaerobic Enzymatic reactions active: 58

# %%
builder = escher.Builder(map_json='primer_iML_map.json', 
                         reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'value', 'value': .01, 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#0000dd', 'size': 20}])
builder.reaction_data = solution.fluxes.to_dict()
builder.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="aqbidmqzmm"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"aqbidmqzmm"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"ALATA_D2": 0.0, "SHCHD2": 0.0, "CPPPGO": 8.937544725795354e-31, "GTHOr": 0.0, "DHORD5": 0.0, "GLYCTO2": 0.0, "GLYCTO3": 0.0, "GLYCTO4": 0.0, "PFK_3": 3.0281690140845146, "TRPS2": 0.0, "G3PD5": 0.0, "EX_acgam_e": 0.0, "EX_cellb_e": 0.0, "EX_chol_e": 0.0, "LEUTAi": 0.0, "SHK3Dr": 0.0, "G5SD": 0.0, "ALATA_L2": 0.0, "MAN6PI": 0.0, "APRAUR": 0.0, "DB4PS": 0.0, "RBFK": 0.0, "ACP1_FMN": 0.0, "RBFSb": 0.0, "EX_pi_e": -8.881784197001249e-15, "EX_h_e": 24.08450704225357, "DMATT": 0.0, "GRTT": 0.0, "UPP3S": 0.0, "UPPDC1": 0.0, "TMDPP": 0.0, "EX_ade_e": 0.0, "EX_4abut_e": 0.0, "EX_ac_e": 7.112676056338047, "EX_akg_e": 0.0, "EX_ala__L_e": 0.0, "EX_arg__L_e": 0.0, "EX_asp__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dcyt_e": 0.0, "EX_fum_e": 0.0, "EX_glu__L_e": 0.0, "EX_gua_e": 0.0, "HCO3E": 2.11545775725878e-30, "IMPC": -0.9154929577464795, "IMPD": 0.0, "ECOAH4": -2.1597511556907337e-31, "GLUTRS": 0.0, "TMPPP": 0.0, "URIK1": 0.0, "URIK2": 0.0, "CYTDK1": 0.0, "CYTDK2": 0.0, "XPPT": 0.0, "HXPRT": 0.0, "NDPK5": 0.0, "DHORTS": 0.0, "OMPDC": 0.0, "CS": 0.0, "ICDHyr": 0.0, "ACALD": -8.02816901408453, "ACS": 0.0, "PPA": 1.8309859154929595, "PPCK": 0.0, "ME1": 0.0, "ALAR": -4.1090104825984814e-17, "ALATA_L": 4.109010482598441e-17, "XYLK": 0.0, "RBK": 10.00000000000003, "GLYK": 6.73245563687283e-17, "PPM": 0.0, "ASPTA": -0.9154929577464852, "FBP": 0.0, "GLGC": 0.0, "PYK": 9.366197183098611, "A5PISO": 1.346491127374566e-16, "EX_met__L_e": 0.0, "EX_metsox_S__L_e": 0.0, "IPPMIb": 0.0, "ACHBS": 0.0, "ACLS": 0.0, "PSCVT": 0.0, "ANS": 0.0, "ANPRT": 0.0, "CHORM": 0.0, "CHORS": 0.0, "IGPS": 0.0, "EX_crn_e": 0.0, "EX_fe3_e": 0.0, "EX_glcn_e": 0.0, "EX_gln__L_e": 0.0, "EX_glyc_e": 0.0, "EX_man_e": 0.0, "EX_mn2_e": 0.0, "EX_